# %%
import sys
sys.path.append("..")
from customplotting.mscope import plot_image, plot_confocal, plot_pixera
# %matplotlib notebook

# %% [markdown]
# ## Plot Image Data with Options to Customize

# %%
"""Generate random img data"""
import numpy as np
img_data = np.random.random(2500)
img_data = np.reshape(img_data, newshape=(50,50))

# %%
"""Plot image data with scalebar in one line"""
plot_image(img_data, "inferno", stepsize=0.1) # default unit is 'um' but can be changed
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Change scalebar parameters

# %%
"""For complete list of parameters refer to docs or print(plot_image.__doc__)"""

plot_image(img_data, "seismic", stepsize=200, units="nm", scalebar_params={'color':'yellow'})
# Out:
# <img src="data:image/png;base64,..." width="640">
